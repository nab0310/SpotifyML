# %%
import pandas as pd #Dataframe, Series
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

import graphviz
import pydotplus
import io
from scipy import misc

# %matplotlib inline

# %% [markdown]
# ## Spotify Song Attributes EDA
# - Import Dataset from https://www.kaggle.com/geomack/spotifyclassification
# - EDA to visualize data and observe structure
# - Train a classifier (Decision Tree)
# - Predict a target using the trained classifier

# %%
data = pd.read_csv('data/mySpotify.csv')

# %%
data.describe()
# Out:
#        acousticness  danceability    duration_ms       energy  \
# count   4002.000000   4002.000000    4002.000000  4002.000000
# mean       0.302971      0.572198  227001.241379     0.608060
# std        0.290055      0.116035   50702.922369     0.204537
# min        0.000011      0.061500   57196.000000     0.006150
# 25%        0.047100      0.501000  195474.250000     0.469000
# 50%        0.202500      0.575000  218869.000000     0.635000
# 75%        0.516000      0.649000  246950.000000     0.777000
# max        0.995000      0.946000  570947.000000     0.994000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       4002.000000  4002.000000  4002.000000  4002.000000  4002.000000
# mean           0.055349     5.282609     0.174001    -7.671725     0.725887
# std            0.178816     3.577729     0.138468     3.525001     0.446122
# min            0.000000     0.000000     0.014300   -30.875000     0.000000
# 25%            0.000000     2.000000     0.096325    -9.413750     0.000000
# 50%            0.000012     5.000000     0.119000    -6.881500     1.000000
# 75%            0.001790     9.000000     0.201000    -5.221750     1.000000
# max            0.970000    11.000000     0.981000    -0.755000     1.000000
#
#        speechiness       target        tempo  time_signature      valence
# count  4002.000000  4002.000000  4002.000000     4002.000000  4002.000000
# mean      0.057859     0.443778   122.445250        3.943778     0.458274
# std       0.057254     0.496891    29.604489        0.287345     0.233365
# min       0.022500     0.000000    52.365000        1.000000     0.030400
# 25%       0.031500     0.000000    99.073250        4.000000     0.271000
# 50%       0.038700     0.000000   121.341000        4.000000     0.443000
# 75%       0.056675     1.000000   142.648000        4.000000     0.640000
# max       0.521000     1.000000   212.484000        5.000000     0.983000

# %%
data.head()
# Out:
#    acousticness                                       analysis_url  \
# 0         0.161  https://api.spotify.com/v1/audio-analysis/7eEl...
# 1         0.223  https://api.spotify.com/v1/audio-analysis/02oA...
# 2         0.285  https://api.spotify.com/v1/audio-analysis/5q4B...
# 3         0.920  https://api.spotify.com/v1/audio-analysis/6Kkt...
# 4         0.030  https://api.spotify.com/v1/audio-analysis/1Dp7...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.787       197236   0.484  7eElVgPcxDqmgGrSwVFI74
# 1         0.757       189796   0.437  02oAUzv4M0ItuTDy2RT3IT
# 2         0.646       271088   0.376  5q4BpnMrYEFzLO0dYODj6J
# 3         0.575       171728   0.220  6Kkt27YmFyIFrcX3QXFi2o
# 4         0.470       367391   0.450  1Dp7JGFNjvg8Nk0CtMCcnr
#
#    instrumentalness  key  liveness  loudness  mode  speechiness  target  \
# 0          0.004740    6    0.1350   -10.338     1       0.1960       1
# 1          0.000001   10    0.0921    -5.540     1       0.0625       1
# 2          0.009510    0    0.0899   -10.054     1       0.0478       1
# 3          0.000000   10    0.0962   -11.178     0       0.0992       1
# 4          0.009280    1    0.0781   -10.963     0       0.2010       1
#
#      tempo  time_signature                                         track_href  \
# 0  107.925               4  https://api.spotify.com/v1/tracks/7eElVgPcxDqm...
# 1  106.953               4  https://api.spotify.com/v1/tracks/02oAUzv4M0It...
# 2  123.172               4  https://api.spotify.com/v1/tracks/5q4BpnMrYEFz...
# 3   81.601               4  https://api.spotify.com/v1/tracks/6Kkt27YmFyIF...
# 4  149.999               4  https://api.spotify.com/v1/tracks/1Dp7JGFNjvg8...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:7eElVgPcxDqmgGrSwVFI74    0.481
# 1  audio_features  spotify:track:02oAUzv4M0ItuTDy2RT3IT    0.235
# 2  audio_features  spotify:track:5q4BpnMrYEFzLO0dYODj6J    0.128
# 3  audio_features  spotify:track:6Kkt27YmFyIFrcX3QXFi2o    0.348
# 4  audio_features  spotify:track:1Dp7JGFNjvg8Nk0CtMCcnr    0.168

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 19 columns):
# acousticness        4002 non-null float64
# analysis_url        4002 non-null object
# danceability        4002 non-null float64
# duration_ms         4002 non-null int64
# energy              4002 non-null float64
# id                  4002 non-null object
# instrumentalness    4002 non-null float64
# key                 4002 non-null int64
# liveness            4002 non-null float64
# loudness            4002 non-null float64
# mode                4002 non-null int64
# speechiness         4002 non-null float64
# target              4002 non-null int64
# tempo               4002 non-null float64
# time_signature      4002 non-null int64
# track_href          4002 non-null object
# type                4002 non-null object
# uri                 4002 non-null object
# valence             4002 non-null float64
# dtypes: float64(9), int64(5), object(5)
# memory usage: 594.1+ KB

# %%
train, test = train_test_split(data, test_size = 0.15)

# %%
print("Training size: {}, Test size: {}".format(len(train),len(test)))
# Out:
# Training size: 3401, Test size: 601

# %%
# Custom Color Palette
red_blue = ['#19B5FE', '#EF4836']
palette = sns.color_palette(red_blue)
sns.set_palette(palette)
sns.set_style('white')

# %%
pos_tempo = data[data['target'] == 1]['tempo']
neg_tempo = data[data['target'] == 0]['tempo']
pos_dance = data[data['target'] == 1]['danceability']
neg_dance = data[data['target'] == 0]['danceability']
pos_duration = data[data['target'] == 1]['duration_ms']
neg_duration = data[data['target'] == 0]['duration_ms']
pos_loudness = data[data['target'] == 1]['loudness']
neg_loudness = data[data['target'] == 0]['loudness']
pos_speechiness = data[data['target'] == 1]['speechiness']
neg_speechiness = data[data['target'] == 0]['speechiness']
pos_valence = data[data['target'] == 1]['valence']
neg_valence = data[data['target'] == 0]['valence']
pos_energy = data[data['target'] == 1]['energy']
neg_energy = data[data['target'] == 0]['energy']
pos_acousticness = data[data['target'] == 1]['acousticness']
neg_acousticness = data[data['target'] == 0]['acousticness']
pos_key = data[data['target'] == 1]['key']
neg_key = data[data['target'] == 0]['key']
pos_instrumentalness = data[data['target'] == 1]['instrumentalness']
neg_instrumentalness = data[data['target'] == 0]['instrumentalness']

# %%
fig = plt.figure(figsize=(12,8))
plt.title("Song Tempo Like / Dislike Distribution")
pos_tempo.hist(alpha=0.7, bins=30, label='positive')
neg_tempo.hist(alpha=0.7, bins=30, label='negative')
plt.legend(loc='upper right')

# %%
fig2 = plt.figure(figsize=(15,15))

#Danceability
ax3 = fig2.add_subplot(331)
ax3.set_xlabel('Danceability')
ax3.set_ylabel('Count')
ax3.set_title('Song Danceability Like Distribution')
pos_dance.hist(alpha= 0.5, bins=30)
ax4 = fig2.add_subplot(331)
neg_dance.hist(alpha= 0.5, bins=30)

#Duration_ms
ax5 = fig2.add_subplot(332)
ax5.set_xlabel('Duration')
ax5.set_ylabel('Count')
ax5.set_title('Song Duration Like Distribution')
pos_duration.hist(alpha= 0.5, bins=30)
ax6 = fig2.add_subplot(332)
neg_duration.hist(alpha= 0.5, bins=30)

#Loudness
ax7 = fig2.add_subplot(333)
ax7.set_xlabel('Loudness')
ax7.set_ylabel('Count')
ax7.set_title('Song Loudness Like Distribution')
pos_loudness.hist(alpha= 0.5, bins=30)
ax8 = fig2.add_subplot(333)
neg_loudness.hist(alpha= 0.5, bins=30)

#Speechiness
ax9 = fig2.add_subplot(334)
ax9.set_xlabel('Speechiness')
ax9.set_ylabel('Count')
ax9.set_title('Song Speechiness Like Distribution')
pos_speechiness.hist(alpha= 0.5, bins=30)
ax10 = fig2.add_subplot(334)
neg_speechiness.hist(alpha= 0.5, bins=30)

#Valence
ax11 = fig2.add_subplot(335)
ax11.set_xlabel('Valence')
ax11.set_ylabel('Count')
ax11.set_title('Song Valence Like Distribution')
pos_valence.hist(alpha= 0.5, bins=30)
ax12 = fig2.add_subplot(335)
neg_valence.hist(alpha= 0.5, bins=30)

#Energy
ax13 = fig2.add_subplot(336)
ax13.set_xlabel('Energy')
ax13.set_ylabel('Count')
ax13.set_title('Song Energy Like Distribution')
pos_energy.hist(alpha= 0.5, bins=30)
ax14 = fig2.add_subplot(336)
neg_energy.hist(alpha= 0.5, bins=30)

#Key
ax15 = fig2.add_subplot(337)
ax15.set_xlabel('Key')
ax15.set_ylabel('Count')
ax15.set_title('Song Key Like Distribution')
pos_key.hist(alpha= 0.5, bins=30)
ax16 = fig2.add_subplot(337)
neg_key.hist(alpha= 0.5, bins=30)

# %%
c = DecisionTreeClassifier(min_samples_split=100)

# %%
#define a set of features for the Decision Tree Classifier to use
features = ["danceability", "loudness", "valence", "energy", "instrumentalness", "acousticness", "key", "speechiness","duration_ms"]

# %%
x_train = train[features]
y_train = train["target"]

x_test = test[features]
y_test = test["target"]

# %%
dt = c.fit(x_train, y_train)

# %%
def show_tree(InputTree, features, path):
    f = io.StringIO()
    tree.export_graphviz(InputTree, out_file=f, feature_names=features)
    pydotplus.graph_from_dot_data(f.getvalue()).write_png(path)
    img = misc.imread(path)
    plt.rcParams["figure.figsize"] = (20,20)
    plt.imshow(img)

# %%
show_tree(dt, features, "dec_tree_01.png")

# %%
y_pred = c.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, y_pred) * 100
print("Accuracy using Decision Tree: ", round(score, 1), "%")
# Out:
# Accuracy using Decision Tree:  79.5 %

# %%
# test = pd.read_csv('data/data.csv')

# new_test_data = test[features]

# pred = c.predict(new_test_data)

# likedSongs = 0
# i = 0
# for prediction in pred:
#     if(prediction == 1):
#         print ("Song: " + test["song_title"][i] + ", By: "+ test["artist"][i])
#         likedSongs= likedSongs + 1
#     i = i +1
# print(likedSongs)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(3)

knn.fit(x_train, y_train)

knn_pred = c.predict(x_test)

from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, knn_pred) * 100
print("Accuracy using Knn Tree: ", round(score, 1), "%")
# Out:
# Accuracy using Knn Tree:  79.5 %

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier()

mlp.fit(x_train, y_train)

mlp_pred = mlp.predict(x_test)

from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, mlp_pred) * 100
print("Accuracy using mlp Tree: ", round(score, 1), "%")
# Out:
# Accuracy using mlp Tree:  46.3 %

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
qda = QuadraticDiscriminantAnalysis()
qda.fit(x_train, y_train)
qda_pred = qda.predict(x_test)
score = accuracy_score(y_test, qda_pred)*100
print("Accuracy using qda: ", round(score, 1), "%")
# Out:
# Accuracy using qda:  74.2 %

# %%
from sklearn.svm import SVC
svc_lin = SVC(kernel="linear", C=0.025)
svc_lin.fit(x_train, y_train)
svc_pred = svc_lin.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, svc_pred) * 100
print("Accuracy using svc linear: ", round(score, 1), "%")
# Out:
# Accuracy using svc linear:  53.9 %

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
gpc = GaussianProcessClassifier(1.0 * RBF(1.0), warm_start=True)
gpc.fit(x_train, y_train)
gpc_pred = gpc.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, gpc_pred) * 100
print("Accuracy using gpc: ", round(score, 1), "%")
# Out:
# Accuracy using gpc linear:  66.1 %

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
forest = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
forest.fit(x_train, y_train)
forest_pred = forest.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, forest_pred) * 100
print("Accuracy using random forest: ", round(score, 1), "%")
ada = AdaBoostClassifier()
ada.fit(x_train, y_train)
ada_pred = ada.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, ada_pred) * 100
print("Accuracy using ada: ", round(score, 1), "%")
# Out:
# Accuracy using random forest:  78.2 %
# Accuracy using ada:  83.4 %

# %%
from sklearn.naive_bayes import GaussianNB
gauss = GaussianNB()
gauss.fit(x_train, y_train)
gauss_pred = gauss.predict(x_test)
score = accuracy_score(y_test, gauss_pred)*100
print("Accuracy using gauss: ", round(score, 1), "%")
# Out:
# Accuracy using gauss:  57.7 %

# %%
import spotipy
import spotipy.util as util
sp = spotipy.Spotify() 
from spotipy.oauth2 import SpotifyClientCredentials 
from random import randint

cid ="CLIENT-ID" 
secret = "SECERT" 
username = "USERNAME"
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
sp.trace=False 
username = "USERNAME"
scope = 'playlist-modify-private playlist-modify-public playlist-read-private user-library-read'
token = util.prompt_for_user_token(username, scope)
#Good Playlist
if token:
    sp = spotipy.Spotify(auth=token)
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=0cadd882a6ab4ff485c80b8b02aa3b0c&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8888&scope=playlist-modify-private+playlist-modify-public+playlist-read-private+user-library-read in your browser
#
#
# Enter the URL you were redirected to: http://localhost:8888/tree?code=AQBxK1gl4wWZRxSYA3CYCPUUERSdz9QneqIS0rY8Nrh3QQIdjYjqBBdxJvZ4IF5E8aUkPVR0En-nPzPBLE94riIQ_Ib_sfzlP07HQBX1jlNUoeGB9hr_vgy7c2zv1Q6v9w7aPEl9yfK54f2S5p9kdqHtjsz5sdoKWfDJ5lUHMM-NVMugrjZmTaW-dRXq7l7VKRHl8Qq8b-WKnkNiQCewj2iKslT6Xi_nQngq_ySl3e62Kqx2YnMwFBEX-nwKyCtRpsuJue2hLm5hB9Q7jn-n59FEk2r5V3DfC8--25Lm7Eun-SuQbyM

# %%
test = pd.read_csv('data/indie.csv')

new_test_data = test[features]

pred = ada.predict(new_test_data)

likedSongs = 0
i = 0
for prediction in pred:
    if(prediction == 1):
        print ("Song: " + test["song_title"][i] + ", By: "+ test["artist"][i])
        sp.user_playlist_add_tracks("1287242681", "4UBCOq1nKHOVBqSuzUq0DT", [test['id'][i]])
        likedSongs= likedSongs + 1
    i = i +1
# Out:
# Song: Talk Too Much, By: COIN
# Song: Drive, By: Oh Wonder
# Song: Stars, By: Future Generations
# Song: Keeping Your Head Up, By: Birdy
# Song: Gone, By: JR JR
# Song: Go Outside, By: Cults
# Song: Wake Up, By: Two Door Cinema Club
# Song: Greek Tragedy, By: The Wombats
# Song: Moving To New York, By: The Wombats
# Song: Chocolate, By: The 1975
# Song: Mr. Brightside, By: The Killers
# Song: Kids, By: MGMT
# Song: Tessellate, By: alt-J
# Song: Unbelievers, By: Vampire Weekend
# Song: T-Shirt Weather, By: Circa Waves
# Song: Trojans, By: Atlas Genius
# Song: Ways To Go, By: Grouplove
# Song: Pink Lemonade, By: The Wombats
# Song: Something Good Can Work, By: Two Door Cinema Club
# Song: Electric Feel, By: MGMT
# Song: Kathleen, By: Catfish and the Bottlemen
# Song: Out Of My League, By: Fitz and The Tantrums
# Song: Undercover Martyn, By: Two Door Cinema Club
# Song: Take Me Out, By: Franz Ferdinand
# Song: Time to Pretend, By: MGMT
# Song: Tokyo - Vampires & Wolves, By: The Wombats
# Song: Breezeblocks, By: alt-J
# Song: Young Folks, By: Peter Bjorn and John
# Song: Hollow Life, By: Coast Modern
# Song: Changing Of The Seasons, By: Two Door Cinema Club
# Song: My Body, By: Young the Giant
# Song: Dreaming, By: Smallpools
# Song: Come a Little Closer, By: Cage The Elephant
# Song: Curveballs, By: The Wombats
# Song: American Money, By: BØRNS
# Song: If I ever feel better, By: Phoenix
# Song: Harlem, By: New Politics
# Song: Electric Love, By: BØRNS
# Song: Cigarette Daydreams, By: Cage The Elephant
# Song: We Come Running, By: Youngblood Hawke
# Song: Beware the Dog, By: The Griswolds
# Song: Handshake, By: Two Door Cinema Club
# Song: I Wanna Get Better, By: Bleachers
# Song: The Way It Was, By: Coast Modern
# Song: Over & Over, By: Smallpools
# Song: Sleep Alone, By: Two Door Cinema Club
# Song: Kathleen, By: Catfish and the Bottlemen
# Song: I Can Talk, By: Two Door Cinema Club
# Song: Sweet Disposition, By: The Temper Trap
# Song: Miracle Mile, By: Cold War Kids
# Song: Souls, By: Hippo Campus
# Song: Rollercoaster, By: Bleachers
# Song: Bad Decisions, By: Two Door Cinema Club
# Song: Guru, By: Coast Modern
# Song: Mason Jar, By: Smallpools
# Song: Bashful Creatures, By: Hippo Campus
# Song: Our Own House, By: MisterWives
# Song: Past Lives, By: BØRNS
# Song: Give Me A Try, By: The Wombats
# Song: Emoticons, By: The Wombats
# Song: Soundcheck, By: Catfish and the Bottlemen
# Song: Got to My Head, By: WATERS
# Song: D-D-Dance, By: The Royal Concept
# Song: Giants, By: Bear Hands
# Song: Your Body Is A Weapon, By: The Wombats
# Song: What's Real, By: WATERS
# Song: Worlds On Fire, By: Zerbin
# Song: If You Wanna Stay, By: The Griswolds
# Song: Cry for Me, By: HUNNY
# Song: You & Me, By: The Hunna
# Song: Get It, By: Matt and Kim
# Song: Wow, By: Beck
# Song: Roll Up, By: Fitz and The Tantrums
# Song: Cocoon, By: Milky Chance
# Song: Childish, By: Night Lights
# Song: Start Somewhere, By: A Yawn Worth Yelling
# Song: Don't Move, By: Phantogram
# Song: Let Me In, By: Grouplove
# Song: Good Morning, By: Grouplove
# Song: Good Morning - Madison Mars Remix, By: Grouplove
# Song: Ultralife, By: Oh Wonder

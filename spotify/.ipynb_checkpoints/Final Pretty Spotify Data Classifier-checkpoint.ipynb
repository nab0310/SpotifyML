# %%
import pandas as pd #Dataframe, Series
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

import graphviz
import pydotplus
import io

from scipy import misc

from sklearn.metrics import accuracy_score

import spotipy
import spotipy.util as util
sp = spotipy.Spotify() 
from spotipy.oauth2 import SpotifyClientCredentials 

# %matplotlib inline

# %% [markdown]
# # Spotify Login
#
# - Once you run this it will redirect you to another page, copy the url and paste it into the dialog box that will pop up below.
# - If you get a bad request the first time and you logged in, just run it again and use the new link

# %%
cid ="0cadd882a6ab4ff485c80b8b02aa3b0c" 
secret = "04d0f737e18a4a92abee1da25d70766b"
username = ""

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

scope = 'user-library-read playlist-read-private'
token = util.prompt_for_user_token(username, scope)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# # Input Data to the Model
# - You need to include the user you want to get the playlist from as well as the playlist id's of your good and bad playlists.
# - To do this go to your good and bad playlists and copy the links.
#     - An example spotify link: https://open.spotify.com/user/1287242681/playlist/5OdH7PmotfAO7qDGxKdw3J
#     - The user is the number after user/ and the playlist id is after the playlist/.
#
# - The method signature is sp.user_playlist('user', 'playlist_id')

# %%
good_playlist = sp.user_playlist("1287242681", "5OdH7PmotfAO7qDGxKdw3J")
bad_playlist = sp.user_playlist("1287242681", "3ySDAXYGUwRrp8C4ejIm9m")

# %%
#Get the good song id's out of the good playlists, need it for the audio features call.
good_tracks = good_playlist["tracks"]
good_songs = good_tracks["items"] 
while good_tracks['next']:
    good_tracks = sp.next(good_tracks)
    for item in good_tracks["items"]:
        good_songs.append(item)
good_ids = [] 
print(len(good_songs))
for i in range(len(good_songs)- 500):
    good_ids.append(good_songs[i]['track']['id'])
good_tracks
# Out:
# 2276
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100',
#  'items': [{'added_at': '2017-09-14T01:10:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'},
#        'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot',
#        'id': '40Ojab0UtVQFjA76qXr8Ot',
#        'name': 'Apparat',
#        'type': 'artist',
#        'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'},
#      'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3',
#      'id': '5jSp45Ft6ly9nXEwXoa7c3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480',
#        'width': 64}],
#      'name': 'Krieg Und Frieden (Music For Theatre)',
#      'type': 'album',
#      'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'},
#       'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot',
#       'id': '40Ojab0UtVQFjA76qXr8Ot',
#       'name': 'Apparat',
#       'type': 'artist',
#       'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 311186,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBR8R1100671'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'},
#     'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl',
#     'id': '3l0pdat6N0XcotNr2b7rNl',
#     'name': 'A Violent Sky',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl'}},
#   {'added_at': '2017-09-14T01:10:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56948uI22Ydxdxnv4inDxB'},
#      'href': 'https://api.spotify.com/v1/albums/56948uI22Ydxdxnv4inDxB',
#      'id': '56948uI22Ydxdxnv4inDxB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8d7e6a9c2309cbd108bd162987b71a2bc05763e5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b6b771a59829382a20f89bb60bed10b8457e6737',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c8347a070ee2b5d81f9be20f879146c21570e086',
#        'width': 64}],
#      'name': 'Progressive Underground',
#      'type': 'album',
#      'uri': 'spotify:album:56948uI22Ydxdxnv4inDxB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'},
#       'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk',
#       'id': '6mIlyUO24xtGVeBDlP8clk',
#       'name': 'Noel Sanger',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 481054,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLF711405504'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'},
#     'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI',
#     'id': '7yswV2iMJGCCkv0QhHQznI',
#     'name': 'One More Time - Solarity Instrumental Mix',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83f4f0a6569d4f33a23b93a51d76b2285aa1fb61?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7yswV2iMJGCCkv0QhHQznI'}},
#   {'added_at': '2017-09-14T01:10:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4CMWzDDlDTg4NBgtO31fsQ'},
#      'href': 'https://api.spotify.com/v1/albums/4CMWzDDlDTg4NBgtO31fsQ',
#      'id': '4CMWzDDlDTg4NBgtO31fsQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e00dc370f477f11e07778375fb9107fe23a23354',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8aa1f66f4b667a2ac03a4884d9f0539552dcbbc3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b877ff6fa1f8023f5cda37d08316e0e01c9c55cd',
#        'width': 64}],
#      'name': 'Different Shores',
#      'type': 'album',
#      'uri': 'spotify:album:4CMWzDDlDTg4NBgtO31fsQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4hpq4qAP5XaJawNi8XriL8'},
#       'href': 'https://api.spotify.com/v1/artists/4hpq4qAP5XaJawNi8XriL8',
#       'id': '4hpq4qAP5XaJawNi8XriL8',
#       'name': 'Silence Groove',
#       'type': 'artist',
#       'uri': 'spotify:artist:4hpq4qAP5XaJawNi8XriL8'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 333252,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBKQU1236589'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4v7XHQoYNFEozggvI1tfro'},
#     'href': 'https://api.spotify.com/v1/tracks/4v7XHQoYNFEozggvI1tfro',
#     'id': '4v7XHQoYNFEozggvI1tfro',
#     'name': 'Underwater Smile - Original Mix',
#     'popularity': 15,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34efe859ea28a10f66d4f098e7f984286f13abf8?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:4v7XHQoYNFEozggvI1tfro'}},
#   {'added_at': '2017-09-14T01:10:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RBdF1pJSLF3ugc2Y2PoB8'},
#        'href': 'https://api.spotify.com/v1/artists/5RBdF1pJSLF3ugc2Y2PoB8',
#        'id': '5RBdF1pJSLF3ugc2Y2PoB8',
#        'name': 'Savant',
#        'type': 'artist',
#        'uri': 'spotify:artist:5RBdF1pJSLF3ugc2Y2PoB8'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6aIvDKKKlpLaviDkMn6LDQ'},
#      'href': 'https://api.spotify.com/v1/albums/6aIvDKKKlpLaviDkMn6LDQ',
#      'id': '6aIvDKKKlpLaviDkMn6LDQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c30b2c2ef80bc1a3813857ccf108d099bb85279c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/19097abd08569ad88fd798dd352da5d0ffc3a203',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ebec279d34c8cbdff9196002d40a60ee05af4789',
#        'width': 64}],
#      'name': 'Alchemist',
#      'type': 'album',
#      'uri': 'spotify:album:6aIvDKKKlpLaviDkMn6LDQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RBdF1pJSLF3ugc2Y2PoB8'},
#       'href': 'https://api.spotify.com/v1/artists/5RBdF1pJSLF3ugc2Y2PoB8',
#       'id': '5RBdF1pJSLF3ugc2Y2PoB8',
#       'name': 'Savant',
#       'type': 'artist',
#       'uri': 'spotify:artist:5RBdF1pJSLF3ugc2Y2PoB8'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 302940,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBKQU1228772'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/60fK6KJtxEhxeSTHbwCn9V'},
#     'href': 'https://api.spotify.com/v1/tracks/60fK6KJtxEhxeSTHbwCn9V',
#     'id': '60fK6KJtxEhxeSTHbwCn9V',
#     'name': 'Redemption - Original Mix',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e16bd3d008fbb8146989aadc085e66d02ce3a506?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:60fK6KJtxEhxeSTHbwCn9V'}},
#   {'added_at': '2017-09-14T01:10:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TaaqqCMRMSpvNHClfnbEL'},
#        'href': 'https://api.spotify.com/v1/artists/6TaaqqCMRMSpvNHClfnbEL',
#        'id': '6TaaqqCMRMSpvNHClfnbEL',
#        'name': 'Maduk',
#        'type': 'artist',
#        'uri': 'spotify:artist:6TaaqqCMRMSpvNHClfnbEL'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5xY8KZP2bCyo8XTXZe5xjM'},
#      'href': 'https://api.spotify.com/v1/albums/5xY8KZP2bCyo8XTXZe5xjM',
#      'id': '5xY8KZP2bCyo8XTXZe5xjM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c2726193e0a2ded48596dd5adf61197d45553d21',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/64fb73fc5cc50e156beab42dbd1b7eaebee80ec1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/e8b14d6de8e2b71fa71f28e109f685d41daa74c1',
#        'width': 64}],
#      'name': 'Feel Good',
#      'type': 'album',
#      'uri': 'spotify:album:5xY8KZP2bCyo8XTXZe5xjM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TaaqqCMRMSpvNHClfnbEL'},
#       'href': 'https://api.spotify.com/v1/artists/6TaaqqCMRMSpvNHClfnbEL',
#       'id': '6TaaqqCMRMSpvNHClfnbEL',
#       'name': 'Maduk',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TaaqqCMRMSpvNHClfnbEL'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 249600,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBTMZ1350033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ecSYEY7SUZk3Uh5auKN3F'},
#     'href': 'https://api.spotify.com/v1/tracks/7ecSYEY7SUZk3Uh5auKN3F',
#     'id': '7ecSYEY7SUZk3Uh5auKN3F',
#     'name': 'Feel Good',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dfd5a59a9b75e15d603adbe5295c3fdb74021bc8?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7ecSYEY7SUZk3Uh5auKN3F'}},
#   {'added_at': '2017-09-14T01:10:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VOR7Ie9xUSb45fzIIVJQ1'},
#        'href': 'https://api.spotify.com/v1/artists/0VOR7Ie9xUSb45fzIIVJQ1',
#        'id': '0VOR7Ie9xUSb45fzIIVJQ1',
#        'name': 'Hammock',
#        'type': 'artist',
#        'uri': 'spotify:artist:0VOR7Ie9xUSb45fzIIVJQ1'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3o33sEH5ycPJV6RGq3hbJ6'},
#      'href': 'https://api.spotify.com/v1/albums/3o33sEH5ycPJV6RGq3hbJ6',
#      'id': '3o33sEH5ycPJV6RGq3hbJ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/962fa635494c9d4e8ca7760a52eb230268c79204',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/dc88e2a7b2ddb23edb32452f48d0ed556cc6fa9d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0a74913cd21c89cd27c3628308ee70004df6fbb4',
#        'width': 64}],
#      'name': 'Departure Songs',
#      'type': 'album',
#      'uri': 'spotify:album:3o33sEH5ycPJV6RGq3hbJ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0VOR7Ie9xUSb45fzIIVJQ1'},
#       'href': 'https://api.spotify.com/v1/artists/0VOR7Ie9xUSb45fzIIVJQ1',
#       'id': '0VOR7Ie9xUSb45fzIIVJQ1',
#       'name': 'Hammock',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VOR7Ie9xUSb45fzIIVJQ1'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 2,
#     'duration_ms': 290466,
#     'explicit': False,
#     'external_ids': {'isrc': 'US7QT1200062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Qxbm5KzZGkpYzApGp4tqq'},
#     'href': 'https://api.spotify.com/v1/tracks/2Qxbm5KzZGkpYzApGp4tqq',
#     'id': '2Qxbm5KzZGkpYzApGp4tqq',
#     'name': 'Tornado Warning',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e18b638f8a0f51cb5be4a5d3fb3b744b2a2b09e8?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2Qxbm5KzZGkpYzApGp4tqq'}},
#   {'added_at': '2017-09-14T01:10:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ksqsOXsqkc1fWsfrpOy3R'},
#        'href': 'https://api.spotify.com/v1/artists/0ksqsOXsqkc1fWsfrpOy3R',
#        'id': '0ksqsOXsqkc1fWsfrpOy3R',
#        'name': 'Ficci',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ksqsOXsqkc1fWsfrpOy3R'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4dvwu7IiRvsFPv8em3ji7T'},
#      'href': 'https://api.spotify.com/v1/albums/4dvwu7IiRvsFPv8em3ji7T',
#      'id': '4dvwu7IiRvsFPv8em3ji7T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b711e02798cd8e4e7de846ff1692a30969233040',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f9948787b1b7fc272a859a6c5cb94b4e4cfde7da',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/005488b1c5ab52e815fc1c4151e1671ff839ad22',
#        'width': 64}],
#      'name': 'While The City Dreams',
#      'type': 'album',
#      'uri': 'spotify:album:4dvwu7IiRvsFPv8em3ji7T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ksqsOXsqkc1fWsfrpOy3R'},
#       'href': 'https://api.spotify.com/v1/artists/0ksqsOXsqkc1fWsfrpOy3R',
#       'id': '0ksqsOXsqkc1fWsfrpOy3R',
#       'name': 'Ficci',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ksqsOXsqkc1fWsfrpOy3R'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 258246,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB-SMU-24-41642'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yCBEoeSKLqXitdLczif0v'},
#     'href': 'https://api.spotify.com/v1/tracks/2yCBEoeSKLqXitdLczif0v',
#     'id': '2yCBEoeSKLqXitdLczif0v',
#     'name': 'While The City Dreams',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e68b8bc27bc296bc7b9dead82a1d8dd0f820894f?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2yCBEoeSKLqXitdLczif0v'}},
#   {'added_at': '2017-09-14T01:10:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0M3cZtjQZ8fz3Hbw1A4CwF'},
#        'href': 'https://api.spotify.com/v1/artists/0M3cZtjQZ8fz3Hbw1A4CwF',
#        'id': '0M3cZtjQZ8fz3Hbw1A4CwF',
#        'name': 'T-Mass',
#        'type': 'artist',
#        'uri': 'spotify:artist:0M3cZtjQZ8fz3Hbw1A4CwF'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03MxwQHDosVnvf4HFjGI79'},
#      'href': 'https://api.spotify.com/v1/albums/03MxwQHDosVnvf4HFjGI79',
#      'id': '03MxwQHDosVnvf4HFjGI79',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/d6d0b9f9529a58099b3ff833a3f3e89e6083c13b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8ddfe0fe6b5ee3d35b97f98c1d376606a684e5c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/8607b4515387fd5b9c4abfe417d1b976f58b89d3',
#        'width': 64}],
#      'name': 'Modulus EP',
#      'type': 'album',
#      'uri': 'spotify:album:03MxwQHDosVnvf4HFjGI79'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0M3cZtjQZ8fz3Hbw1A4CwF'},
#       'href': 'https://api.spotify.com/v1/artists/0M3cZtjQZ8fz3Hbw1A4CwF',
#       'id': '0M3cZtjQZ8fz3Hbw1A4CwF',
#       'name': 'T-Mass',
#       'type': 'artist',
#       'uri': 'spotify:artist:0M3cZtjQZ8fz3Hbw1A4CwF'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 230000,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLD681302891'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/533IEVbdEh7BEx19aQtLqw'},
#     'href': 'https://api.spotify.com/v1/tracks/533IEVbdEh7BEx19aQtLqw',
#     'id': '533IEVbdEh7BEx19aQtLqw',
#     'name': 'Beauty in Thirds',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:533IEVbdEh7BEx19aQtLqw'}},
#   {'added_at': '2017-09-14T01:10:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rRCb7ks1ucmXlyqBoFDlw'},
#        'href': 'https://api.spotify.com/v1/artists/3rRCb7ks1ucmXlyqBoFDlw',
#        'id': '3rRCb7ks1ucmXlyqBoFDlw',
#        'name': 'Stan SB',
#        'type': 'artist',
#        'uri': 'spotify:artist:3rRCb7ks1ucmXlyqBoFDlw'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64dV82etlHE3xOEp77xaJT'},
#      'href': 'https://api.spotify.com/v1/albums/64dV82etlHE3xOEp77xaJT',
#      'id': '64dV82etlHE3xOEp77xaJT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9919f1d26d059f33fa1e62f7d0d1b11ac4f876e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/910dfdfe455f57ed3c3e53a0453445bc52b35444',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a7ffa821db66d9b1ce53261acc4f8a4a801bd5d6',
#        'width': 64}],
#      'name': 'Anyone Out There EP',
#      'type': 'album',
#      'uri': 'spotify:album:64dV82etlHE3xOEp77xaJT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rRCb7ks1ucmXlyqBoFDlw'},
#       'href': 'https://api.spotify.com/v1/artists/3rRCb7ks1ucmXlyqBoFDlw',
#       'id': '3rRCb7ks1ucmXlyqBoFDlw',
#       'name': 'Stan SB',
#       'type': 'artist',
#       'uri': 'spotify:artist:3rRCb7ks1ucmXlyqBoFDlw'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 375841,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB7H81200023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ryawd1Tj2c0y4ddq6X0Nu'},
#     'href': 'https://api.spotify.com/v1/tracks/0ryawd1Tj2c0y4ddq6X0Nu',
#     'id': '0ryawd1Tj2c0y4ddq6X0Nu',
#     'name': 'Dead - Original Mix',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b97500642ccbaa834daf95ccfb36c33e41c2da7f?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ryawd1Tj2c0y4ddq6X0Nu'}},
#   {'added_at': '2017-09-14T01:10:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WhvgoOwfFRjuHf7zgCptu'},
#        'href': 'https://api.spotify.com/v1/artists/3WhvgoOwfFRjuHf7zgCptu',
#        'id': '3WhvgoOwfFRjuHf7zgCptu',
#        'name': 'Koda',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WhvgoOwfFRjuHf7zgCptu'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LvHip3eEa65julqpRzhqK'},
#      'href': 'https://api.spotify.com/v1/albums/0LvHip3eEa65julqpRzhqK',
#      'id': '0LvHip3eEa65julqpRzhqK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c57ee546dcdf1ad461474586d3985d7fe606d531',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/a27a47c26c2ed1b4f3b27dae0e81d901aaaecedf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9e1a664a7a3cb76c826c263d5c170a5c1810f59f',
#        'width': 64}],
#      'name': 'Myrina',
#      'type': 'album',
#      'uri': 'spotify:album:0LvHip3eEa65julqpRzhqK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WhvgoOwfFRjuHf7zgCptu'},
#       'href': 'https://api.spotify.com/v1/artists/3WhvgoOwfFRjuHf7zgCptu',
#       'id': '3WhvgoOwfFRjuHf7zgCptu',
#       'name': 'Koda',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WhvgoOwfFRjuHf7zgCptu'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 316000,
#     'explicit': False,
#     'external_ids': {'isrc': 'US83Z1317953'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6MogRPQGSiUZRNKQVNuGz8'},
#     'href': 'https://api.spotify.com/v1/tracks/6MogRPQGSiUZRNKQVNuGz8',
#     'id': '6MogRPQGSiUZRNKQVNuGz8',
#     'name': 'Hands',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca0a48913c397b099b24ff5d115ffb3648eb25f5?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6MogRPQGSiUZRNKQVNuGz8'}},
#   {'added_at': '2017-09-14T01:10:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oOhM2DFWab8XhSdQiITry'},
#        'href': 'https://api.spotify.com/v1/artists/5oOhM2DFWab8XhSdQiITry',
#        'id': '5oOhM2DFWab8XhSdQiITry',
#        'name': 'Tycho',
#        'type': 'artist',
#        'uri': 'spotify:artist:5oOhM2DFWab8XhSdQiITry'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6KdpI73cSghcgMdV04SSBn'},
#      'href': 'https://api.spotify.com/v1/albums/6KdpI73cSghcgMdV04SSBn',
#      'id': '6KdpI73cSghcgMdV04SSBn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3e30a6809be2c6b25421eb9c8fce47a914053a18',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/bda1b13e5d4a9445d51fcb881ab0b07ba339d5f3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/38df8118af855dc6d7a9cfc0b60cd4dfa1659514',
#        'width': 64}],
#      'name': 'Past Is Prologue',
#      'type': 'album',
#      'uri': 'spotify:album:6KdpI73cSghcgMdV04SSBn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oOhM2DFWab8XhSdQiITry'},
#       'href': 'https://api.spotify.com/v1/artists/5oOhM2DFWab8XhSdQiITry',
#       'id': '5oOhM2DFWab8XhSdQiITry',
#       'name': 'Tycho',
#       'type': 'artist',
#       'uri': 'spotify:artist:5oOhM2DFWab8XhSdQiITry'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 261293,
#     'explicit': False,
#     'external_ids': {'isrc': 'US2J71011309'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0FokXo9HqLXMr4AyVemlcb'},
#     'href': 'https://api.spotify.com/v1/tracks/0FokXo9HqLXMr4AyVemlcb',
#     'id': '0FokXo9HqLXMr4AyVemlcb',
#     'name': 'Cloud Generator',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f81b3d87826e7b709624a3da45d70c4105dc953a?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:0FokXo9HqLXMr4AyVemlcb'}},
#   {'added_at': '2017-09-14T01:10:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1m0rmoX1ma9A5HObTSNcqG'},
#        'href': 'https://api.spotify.com/v1/artists/1m0rmoX1ma9A5HObTSNcqG',
#        'id': '1m0rmoX1ma9A5HObTSNcqG',
#        'name': 'Arkasia',
#        'type': 'artist',
#        'uri': 'spotify:artist:1m0rmoX1ma9A5HObTSNcqG'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3JpzeY2uhkahhmzaJ4LfLk'},
#      'href': 'https://api.spotify.com/v1/albums/3JpzeY2uhkahhmzaJ4LfLk',
#      'id': '3JpzeY2uhkahhmzaJ4LfLk',
#      'images': [{'height': 600,
#        'url': 'https://i.scdn.co/image/095e703f20a229402751d833cee013a080c21175',
#        'width': 600},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/4ebcbb0f6127f4cb501b985d5581c441230fe231',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/cc2e3310b97ac30a92de3760de89122b2a8447b0',
#        'width': 64}],
#      'name': 'Epilogue',
#      'type': 'album',
#      'uri': 'spotify:album:3JpzeY2uhkahhmzaJ4LfLk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1m0rmoX1ma9A5HObTSNcqG'},
#       'href': 'https://api.spotify.com/v1/artists/1m0rmoX1ma9A5HObTSNcqG',
#       'id': '1m0rmoX1ma9A5HObTSNcqG',
#       'name': 'Arkasia',
#       'type': 'artist',
#       'uri': 'spotify:artist:1m0rmoX1ma9A5HObTSNcqG'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 368258,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLZJ1268572'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4m4LC0U6Fta39SfI6ex28o'},
#     'href': 'https://api.spotify.com/v1/tracks/4m4LC0U6Fta39SfI6ex28o',
#     'id': '4m4LC0U6Fta39SfI6ex28o',
#     'name': 'Invisible Bridge - Original Mix',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b017426a98fa367b1d1f41e86737567e40536dab?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4m4LC0U6Fta39SfI6ex28o'}},
#   {'added_at': '2017-09-14T01:10:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74yueOpxONIcPCjGyF84jG'},
#        'href': 'https://api.spotify.com/v1/artists/74yueOpxONIcPCjGyF84jG',
#        'id': '74yueOpxONIcPCjGyF84jG',
#        'name': 'Tom Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:74yueOpxONIcPCjGyF84jG'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0xSXYkqEMgQEFB7dNZ3WAe'},
#      'href': 'https://api.spotify.com/v1/albums/0xSXYkqEMgQEFB7dNZ3WAe',
#      'id': '0xSXYkqEMgQEFB7dNZ3WAe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/241d9ccb59bc2ce76584a9f77edb4a4ea586b6b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/13790ffdffc7fa06f88c531dee16f41ee9a6ceb4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9c8203dd75e9dc0b41e5b3692bf1e73990bf6b76',
#        'width': 64}],
#      'name': '2012',
#      'type': 'album',
#      'uri': 'spotify:album:0xSXYkqEMgQEFB7dNZ3WAe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74yueOpxONIcPCjGyF84jG'},
#       'href': 'https://api.spotify.com/v1/artists/74yueOpxONIcPCjGyF84jG',
#       'id': '74yueOpxONIcPCjGyF84jG',
#       'name': 'Tom Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:74yueOpxONIcPCjGyF84jG'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 395294,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCABR1313304'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5gtDiiZ16Kd5ZmEry3Zw59'},
#     'href': 'https://api.spotify.com/v1/tracks/5gtDiiZ16Kd5ZmEry3Zw59',
#     'id': '5gtDiiZ16Kd5ZmEry3Zw59',
#     'name': 'Who We Want to Be',
#     'popularity': 1,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5gtDiiZ16Kd5ZmEry3Zw59'}},
#   {'added_at': '2017-09-14T01:10:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WhvgoOwfFRjuHf7zgCptu'},
#        'href': 'https://api.spotify.com/v1/artists/3WhvgoOwfFRjuHf7zgCptu',
#        'id': '3WhvgoOwfFRjuHf7zgCptu',
#        'name': 'Koda',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WhvgoOwfFRjuHf7zgCptu'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/54cUYzd8rYD0QIgzSACyn8'},
#      'href': 'https://api.spotify.com/v1/albums/54cUYzd8rYD0QIgzSACyn8',
#      'id': '54cUYzd8rYD0QIgzSACyn8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/29afbc8423705026d3b6bc2aaf97b43a75681e1c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/396e85a0669d7265acf97bfcbbbb74687881c801',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/33d6c0e8cdffd5bd0e6d4a3e1763a559eaca5d1c',
#        'width': 64}],
# ...
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4bazJLWIv8CuqmgxJRiGqo'},
#        'href': 'https://api.spotify.com/v1/artists/4bazJLWIv8CuqmgxJRiGqo',
#        'id': '4bazJLWIv8CuqmgxJRiGqo',
#        'name': 'Just Kiddin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4bazJLWIv8CuqmgxJRiGqo'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6v0BFPLKZrCf0l2qjJ6Dfu'},
#      'href': 'https://api.spotify.com/v1/albums/6v0BFPLKZrCf0l2qjJ6Dfu',
#      'id': '6v0BFPLKZrCf0l2qjJ6Dfu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1ee246905715d21d7dc237c0bfa051d0a61b3707',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/4084effb4e8f1b8925ded733c862bcc336b382cb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d1889f8d32a519150ab800e21161c6bf8aaff57f',
#        'width': 64}],
#      'name': 'Wildlife ep',
#      'type': 'album',
#      'uri': 'spotify:album:6v0BFPLKZrCf0l2qjJ6Dfu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4bazJLWIv8CuqmgxJRiGqo'},
#       'href': 'https://api.spotify.com/v1/artists/4bazJLWIv8CuqmgxJRiGqo',
#       'id': '4bazJLWIv8CuqmgxJRiGqo',
#       'name': 'Just Kiddin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4bazJLWIv8CuqmgxJRiGqo'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 329405,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITN601200025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0kOAb3xuZgllRnqWnRgkBn'},
#     'href': 'https://api.spotify.com/v1/tracks/0kOAb3xuZgllRnqWnRgkBn',
#     'id': '0kOAb3xuZgllRnqWnRgkBn',
#     'name': 'Paloma (Bit Funk Remix)',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e6635a79b36466b630b9a664fce779feb183a7fd?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0kOAb3xuZgllRnqWnRgkBn'}},
#   {'added_at': '2017-09-14T01:11:04Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CiuuHKIxxJPoNRvF94GtR'},
#        'href': 'https://api.spotify.com/v1/artists/3CiuuHKIxxJPoNRvF94GtR',
#        'id': '3CiuuHKIxxJPoNRvF94GtR',
#        'name': 'Veela',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CiuuHKIxxJPoNRvF94GtR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RQ9kYbHisp1UUbnfwHNeU'},
#        'href': 'https://api.spotify.com/v1/artists/6RQ9kYbHisp1UUbnfwHNeU',
#        'id': '6RQ9kYbHisp1UUbnfwHNeU',
#        'name': 'Feint',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RQ9kYbHisp1UUbnfwHNeU'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4bFZOZLmds6jjxpiIk2fMN'},
#      'href': 'https://api.spotify.com/v1/albums/4bFZOZLmds6jjxpiIk2fMN',
#      'id': '4bFZOZLmds6jjxpiIk2fMN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2954852751ec9862c40749236ea66375553fa631',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/100620e22d9cfe1c132ba5e9a18c6e2a501f6260',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/804b9f1c255b5cde401e4cbe164932d99e233f77',
#        'width': 64}],
#      'name': 'Horizons EP',
#      'type': 'album',
#      'uri': 'spotify:album:4bFZOZLmds6jjxpiIk2fMN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hfjEzzSLXPpjkboH8T3rh'},
#       'href': 'https://api.spotify.com/v1/artists/7hfjEzzSLXPpjkboH8T3rh',
#       'id': '7hfjEzzSLXPpjkboH8T3rh',
#       'name': 'Bustre',
#       'type': 'artist',
#       'uri': 'spotify:artist:7hfjEzzSLXPpjkboH8T3rh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RQ9kYbHisp1UUbnfwHNeU'},
#       'href': 'https://api.spotify.com/v1/artists/6RQ9kYbHisp1UUbnfwHNeU',
#       'id': '6RQ9kYbHisp1UUbnfwHNeU',
#       'name': 'Feint',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RQ9kYbHisp1UUbnfwHNeU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3CiuuHKIxxJPoNRvF94GtR'},
#       'href': 'https://api.spotify.com/v1/artists/3CiuuHKIxxJPoNRvF94GtR',
#       'id': '3CiuuHKIxxJPoNRvF94GtR',
#       'name': 'Veela',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CiuuHKIxxJPoNRvF94GtR'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 356824,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB7H81200016'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6s9Y9HX0Sq6GE5HXxUzHvV'},
#     'href': 'https://api.spotify.com/v1/tracks/6s9Y9HX0Sq6GE5HXxUzHvV',
#     'id': '6s9Y9HX0Sq6GE5HXxUzHvV',
#     'name': 'Horizons Feat. Veela - Bustre Remix',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/766eee0b847f17e2485980f35180b7f963c5f9f3?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6s9Y9HX0Sq6GE5HXxUzHvV'}},
#   {'added_at': '2017-09-14T01:11:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yRkgZyRXaO7oh1hTEyKNo'},
#        'href': 'https://api.spotify.com/v1/artists/7yRkgZyRXaO7oh1hTEyKNo',
#        'id': '7yRkgZyRXaO7oh1hTEyKNo',
#        'name': 'Smooth',
#        'type': 'artist',
#        'uri': 'spotify:artist:7yRkgZyRXaO7oh1hTEyKNo'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wuxmCitEXbnexdXdDhh0v'},
#      'href': 'https://api.spotify.com/v1/albums/4wuxmCitEXbnexdXdDhh0v',
#      'id': '4wuxmCitEXbnexdXdDhh0v',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f83fe7581f89b745f9c114eb8958332fe953815',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1defa1377ef22c4400626e9dc15080c860520d17',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/023be15c071016778057ccd6eca60ebd446489b3',
#        'width': 64}],
#      'name': 'Blinded By The Light EP (feat. Shaz Sparks)',
#      'type': 'album',
#      'uri': 'spotify:album:4wuxmCitEXbnexdXdDhh0v'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yRkgZyRXaO7oh1hTEyKNo'},
#       'href': 'https://api.spotify.com/v1/artists/7yRkgZyRXaO7oh1hTEyKNo',
#       'id': '7yRkgZyRXaO7oh1hTEyKNo',
#       'name': 'Smooth',
#       'type': 'artist',
#       'uri': 'spotify:artist:7yRkgZyRXaO7oh1hTEyKNo'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 291397,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBTMZ1100134'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7A77QnN8DGfQvf47k4FyMg'},
#     'href': 'https://api.spotify.com/v1/tracks/7A77QnN8DGfQvf47k4FyMg',
#     'id': '7A77QnN8DGfQvf47k4FyMg',
#     'name': 'Blinded By the Light',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/85be802bbc5467b5067086f7dca113316591e745?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7A77QnN8DGfQvf47k4FyMg'}},
#   {'added_at': '2017-09-14T01:11:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'},
#     'href': 'https://api.spotify.com/v1/users/1287242681',
#     'id': '1287242681',
#     'type': 'user',
#     'uri': 'spotify:user:1287242681'},
#    'is_local': False,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16yUpGkBRgc2eDMd3bB3Uw'},
#        'href': 'https://api.spotify.com/v1/artists/16yUpGkBRgc2eDMd3bB3Uw',
#        'id': '16yUpGkBRgc2eDMd3bB3Uw',
#        'name': 'Mitis',
#        'type': 'artist',
#        'uri': 'spotify:artist:16yUpGkBRgc2eDMd3bB3Uw'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2AepLc5ie9zsxhIdOaDu9i'},
#      'href': 'https://api.spotify.com/v1/albums/2AepLc5ie9zsxhIdOaDu9i',
#      'id': '2AepLc5ie9zsxhIdOaDu9i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/dfdb43f886d5eef5ae04cb8591d0c7964e79a19c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/6b0c2ed68d9c9b091acfee585b542526da6eb642',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ae2432aff23b860cdb66bc6e778463156b46a565',
#        'width': 64}],
#      'name': 'Life Of Sin Series',
#      'type': 'album',
#      'uri': 'spotify:album:2AepLc5ie9zsxhIdOaDu9i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16yUpGkBRgc2eDMd3bB3Uw'},
#       'href': 'https://api.spotify.com/v1/artists/16yUpGkBRgc2eDMd3bB3Uw',
#       'id': '16yUpGkBRgc2eDMd3bB3Uw',
#       'name': 'Mitis',
#       'type': 'artist',
#       'uri': 'spotify:artist:16yUpGkBRgc2eDMd3bB3Uw'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 256875,
#     'explicit': False,
#     'external_ids': {'isrc': 'CA5KR1507448'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5koAhiFXhkaQFyB3afEuFC'},
#     'href': 'https://api.spotify.com/v1/tracks/5koAhiFXhkaQFyB3afEuFC',
#     'id': '5koAhiFXhkaQFyB3afEuFC',
#     'name': 'Life Of Sin Pt. 2 - Original Mix',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3d596008186b16546f556c81a440186e87d00ce5?cid=0cadd882a6ab4ff485c80b8b02aa3b0c',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5koAhiFXhkaQFyB3afEuFC'}}],
#  'limit': 100,
#  'next': None,
#  'offset': 2200,
#  'previous': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2100&limit=100',
#  'total': 2276}

# %%
#Now do the same thing for the bad playlist
bad_tracks = bad_playlist["tracks"]
bad_songs = bad_tracks["items"] 
while bad_tracks['next']:
    bad_tracks = sp.next(bad_tracks)
    for item in bad_tracks["items"]:
        bad_songs.append(item)
bad_ids = [] 
print(len(bad_songs))
for i in range(len(bad_songs)):
    bad_ids.append(bad_songs[i]['track']['id'])
# Out:
# 2226

# %%
good_artist_pop = []
bad_artist_pop = []
for i in range(0,len(good_tracks)):
    print(good_tracks[])
    #good_artist_pop.append(sp.artist(good_tracks[i]['track']['artists'][0]['id'])['popularity'])
    
#for track in bad_tracks:
 #   popularity = sp.artist(track['track']['artists'][0]['id'])['popularity']
  #  bad_artist_pop.append(populartiy)
# Out:
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...
# {'href': 'https://api.spotify.com/v1/users/1287242681/playlists/5OdH7PmotfAO7qDGxKdw3J/tracks?offset=2200&limit=100', 'offset': 2200, 'next': None, 'items': [{'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/3l0pdat6N0XcotNr2b7rNl'}, 'href': 'https://api.spotify.com/v1/tracks/3l0pdat6N0XcotNr2b7rNl', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'name': 'A Violent Sky', 'id': '3l0pdat6N0XcotNr2b7rNl', 'external_ids': {'isrc': 'GBR8R1100671'}, 'track_number': 10, 'uri': 'spotify:track:3l0pdat6N0XcotNr2b7rNl', 'popularity': 26, 'preview_url': 'https://p.scdn.co/mp3-preview/b3479c513d71c19557830ac090e68aaa4f800f4d?cid=0cadd882a6ab4ff485c80b8b02aa3b0c', 'album': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5jSp45Ft6ly9nXEwXoa7c3'}, 'type': 'album', 'uri': 'spotify:album:5jSp45Ft6ly9nXEwXoa7c3', 'href': 'https://api.spotify.com/v1/albums/5jSp45Ft6ly9nXEwXoa7c3', 'name': 'Krieg Und Frieden (Music For Theatre)', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Ojab0UtVQFjA76qXr8Ot'}, 'href': 'https://api.spotify.com/v1/artists/40Ojab0UtVQFjA76qXr8Ot', 'name': 'Apparat', 'type': 'artist', 'id': '40Ojab0UtVQFjA76qXr8Ot', 'uri': 'spotify:artist:40Ojab0UtVQFjA76qXr8Ot'}], 'id': '5jSp45Ft6ly9nXEwXoa7c3', 'album_type': 'album', 'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/c62e95be9066eb9f19c1be31d23f7b7f14ccf5b4'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/24e318f8cac9097594e36ad32c30bafd6cf2d746'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/dfd3a5c00d441ea0262675fbf8333e61d6f77480'}]}, 'duration_ms': 311186, 'type': 'track', 'disc_number': 1, 'explicit': False}, 'is_local': False, 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1287242681'}, 'uri': 'spotify:user:1287242681', 'href': 'https://api.spotify.com/v1/users/1287242681', 'type': 'user', 'id': '1287242681'}}, {'added_at': '2017-09-14T01:10:31Z', 'track': {'available_markets': ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TH', 'TR', 'TW', 'US', 'UY', 'VN'], 'external_urls': {'spotify': 'https://open.spotify.com/track/7yswV2iMJGCCkv0QhHQznI'}, 'href': 'https://api.spotify.com/v1/tracks/7yswV2iMJGCCkv0QhHQznI', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mIlyUO24xtGVeBDlP8clk'}, 'href': 'https://api.spotify.com/v1/artists/6mIlyUO24xtGVeBDlP8clk', 'name': 'Noel Sanger', 'type': 'artist', 'id': '6mIlyUO24xtGVeBDlP8clk', 'uri': 'spotify:artist:6mIlyUO24xtGVeBDlP8clk'}], 'name': 'One More Time - Solarity Instrumental Mix', 'id': '7yswV2iMJGCCkv0QhHQznI', 'external_ids' ...

# %%
#Here is where we get all of the audio_features for the tracks on the good and bad playlists.
features = []
inSavedTracks = []
j = 0
for i in range(0,len(good_ids),50):
    audio_features = sp.audio_features(good_ids[i:i+50])
    for track in audio_features:
        features.append(track)
        track = good_songs[j]
        j= j+1
        features[-1]['trackPopularity'] = track['track']['popularity']
        features[-1]['artistPopularity'] = sp.artist(track['track']['artists'][0]['id'])['popularity']
        features[-1]['target'] = 1
j = 0
for i in range(0,len(bad_ids),50):
    audio_features = sp.audio_features(bad_ids[i:i+50])
    for track in audio_features:
        features.append(track)
        track = good_songs[j]
        j= j+1
        features[-1]['trackPopularity'] = track['track']['popularity']
        features[-1]['artistPopularity'] = sp.artist(track['track']['artists'][0]['id'])['popularity']
        features[-1]['target'] = 0
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-022cbfc9301e> in <module>()
#      10         j= j+1
#      11         features[-1]['trackPopularity'] = track['track']['popularity']
# ---> 12         features[-1]['artistPopularity'] = sp.artist(track['track']['artists'][0]['id'])['popularity']
#      13         features[-1]['target'] = 1
#      14 j = 0
#
# /usr/local/lib/python3.5/dist-packages/spotipy/client.py in artist(self, artist_id)
#     242
#     243         trid = self._get_id('artist', artist_id)
# --> 244         return self._get('artists/' + trid)
#     245
#     246     def artists(self, artists):
#
# /usr/local/lib/python3.5/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# /usr/local/lib/python3.5/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     121             if r.text and len(r.text) > 0 and r.text != 'null':
#     122                 raise SpotifyException(r.status_code,
# --> 123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
#     124                     headers=r.headers)
#     125             else:
#
# /usr/lib/python3/dist-packages/requests/models.py in json(self, **kwargs)
#     806                     # used.
#     807                     pass
# --> 808         return complexjson.loads(self.text, **kwargs)
#     809
#     810     @property
#
# /usr/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /usr/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Model Training and Data Modeling
# - Now that we have the data on what songs you like and don't like let's visualize some of that info.

# %%
trainingData = pd.DataFrame(features)
trainingData.head()
# Out:
#    acousticness                                       analysis_url  \
# 0         0.161  https://api.spotify.com/v1/audio-analysis/7eEl...
# 1         0.223  https://api.spotify.com/v1/audio-analysis/02oA...
# 2         0.285  https://api.spotify.com/v1/audio-analysis/5q4B...
# 3         0.920  https://api.spotify.com/v1/audio-analysis/6Kkt...
# 4         0.030  https://api.spotify.com/v1/audio-analysis/1Dp7...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.787       197236   0.484  7eElVgPcxDqmgGrSwVFI74
# 1         0.757       189796   0.437  02oAUzv4M0ItuTDy2RT3IT
# 2         0.646       271088   0.376  5q4BpnMrYEFzLO0dYODj6J
# 3         0.575       171728   0.220  6Kkt27YmFyIFrcX3QXFi2o
# 4         0.470       367391   0.450  1Dp7JGFNjvg8Nk0CtMCcnr
#
#    instrumentalness  key  liveness  loudness  mode  speechiness  target  \
# 0          0.004740    6    0.1350   -10.338     1       0.1960       1
# 1          0.000001   10    0.0921    -5.540     1       0.0625       1
# 2          0.009510    0    0.0899   -10.054     1       0.0478       1
# 3          0.000000   10    0.0962   -11.178     0       0.0992       1
# 4          0.009280    1    0.0781   -10.963     0       0.2010       1
#
#      tempo  time_signature  trackPopularity  \
# 0  107.925               4               51
# 1  106.953               4               54
# 2  123.172               4               52
# 3   81.601               4               57
# 4  149.999               4               50
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/7eElVgPcxDqm...  audio_features
# 1  https://api.spotify.com/v1/tracks/02oAUzv4M0It...  audio_features
# 2  https://api.spotify.com/v1/tracks/5q4BpnMrYEFz...  audio_features
# 3  https://api.spotify.com/v1/tracks/6Kkt27YmFyIF...  audio_features
# 4  https://api.spotify.com/v1/tracks/1Dp7JGFNjvg8...  audio_features
#
#                                     uri  valence
# 0  spotify:track:7eElVgPcxDqmgGrSwVFI74    0.485
# 1  spotify:track:02oAUzv4M0ItuTDy2RT3IT    0.232
# 2  spotify:track:5q4BpnMrYEFzLO0dYODj6J    0.142
# 3  spotify:track:6Kkt27YmFyIFrcX3QXFi2o    0.351
# 4  spotify:track:1Dp7JGFNjvg8Nk0CtMCcnr    0.175

# %% [markdown]
# - In training this classifier, we need so split our data into training and testing data so our classifier has things to train on and then test if it is right

# %%
train, test = train_test_split(trainingData, test_size = 0.15)
print("Training size: {}, Test size: {}".format(len(train),len(test)))
# Out:
# Training size: 3401, Test size: 601

# %%
# Custom Color Palette for graphs
red_blue = ['#19B5FE', '#EF4836']
palette = sns.color_palette(red_blue)
sns.set_palette(palette)
sns.set_style('white')

# %% [markdown]
# # Graphs!!!!!!!

# %% [markdown]
# 1) First, break out all of the data into positive and negative categories for all the features we want to compare
#
# Also, I know there has to be a better way of doing this, but copy paste is my friend. :)

# %%
pos_tempo = trainingData[trainingData['target'] == 1]['tempo']
neg_tempo = trainingData[trainingData['target'] == 0]['tempo']
pos_dance = trainingData[trainingData['target'] == 1]['danceability']
neg_dance = trainingData[trainingData['target'] == 0]['danceability']
pos_duration = trainingData[trainingData['target'] == 1]['duration_ms']
neg_duration = trainingData[trainingData['target'] == 0]['duration_ms']
pos_loudness = trainingData[trainingData['target'] == 1]['loudness']
neg_loudness = trainingData[trainingData['target'] == 0]['loudness']
pos_speechiness = trainingData[trainingData['target'] == 1]['speechiness']
neg_speechiness = trainingData[trainingData['target'] == 0]['speechiness']
pos_valence = trainingData[trainingData['target'] == 1]['valence']
neg_valence = trainingData[trainingData['target'] == 0]['valence']
pos_energy = trainingData[trainingData['target'] == 1]['energy']
neg_energy = trainingData[trainingData['target'] == 0]['energy']
pos_acousticness = trainingData[trainingData['target'] == 1]['acousticness']
neg_acousticness = trainingData[trainingData['target'] == 0]['acousticness']
pos_key = trainingData[trainingData['target'] == 1]['key']
neg_key = trainingData[trainingData['target'] == 0]['key']
pos_instrumentalness = trainingData[trainingData['target'] == 1]['instrumentalness']
neg_instrumentalness = trainingData[trainingData['target'] == 0]['instrumentalness']
pos_popularity = trainingData[trainingData['target'] == 1]['trackPopularity']
neg_popularity = trainingData[trainingData['target'] == 0]['trackPopularity']

# %%
print(pos_popularity)
print(neg_popularity)
# Out:
# 0       51
# 1       54
# 2       52
# 3       57
# 4       50
# 5       49
# 6       50
# 7       53
# 8       46
# 9       56
# 10      47
# 11      54
# 12      60
# 13      59
# 14      50
# 15      46
# 16      52
# 17      50
# 18      47
# 19      47
# 20      48
# 21      51
# 22      47
# 23      53
# 24      62
# 25      58
# 26      44
# 27      47
# 28      50
# 29      54
#         ..
# 1746     1
# 1747     0
# 1748    57
# 1749    59
# 1750    32
# 1751    41
# 1752    30
# 1753    36
# 1754    47
# 1755    42
# 1756    41
# 1757    59
# 1758    35
# 1759    37
# 1760    62
# 1761    14
# 1762    31
# 1763    23
# 1764    30
# 1765    30
# 1766    20
# 1767     0
# 1768     0
# 1769    23
# 1770    31
# 1771    37
# 1772    33
# 1773    36
# 1774     0
# 1775     0
# Name: trackPopularity, Length: 1776, dtype: int64
# 1776    51
# 1777    54
# 1778    52
# 1779    57
# 1780    50
# 1781    49
# 1782    50
# 1783    53
# 1784    46
# 1785    56
# 1786    47
# 1787    54
# 1788    60
# 1789    59
# 1790    50
# 1791    46
# 1792    52
# 1793    50
# 1794    47
# 1795    47
# 1796    48
# 1797    51
# 1798    47
# 1799    53
# 1800    62
# 1801    58
# 1802    44
# 1803    47
# 1804    50
# 1805    54
#         ..
# 3972    24
# 3973    31
# 3974    41
# 3975     1
# 3976    26
# 3977    16
# 3978    15
# 3979    32
# 3980    44
# 3981    25
# 3982    29
# 3983     0
# 3984    37
# 3985    34
# 3986    38
# 3987    22
# 3988     1
# 3989    38
# 3990    37
# 3991    14
# 3992    30
# 3993    15
# 3994    36
# 3995    35
# 3996    39
# 3997     2
# 3998    38
# 3999    33
# 4000    52
# 4001    25
# Name: trackPopularity, Length: 2226, dtype: int64

# %%
fig = plt.figure(figsize=(12,8))
plt.title("Song Tempo Like / Dislike Distribution")
pos_tempo.hist(alpha=0.7, bins=30, label='positive')
neg_tempo.hist(alpha=0.7, bins=30, label='negative')
plt.legend(loc='upper right')

# %%
fig2 = plt.figure(figsize=(15,15))

#Danceability
ax3 = fig2.add_subplot(331)
ax3.set_xlabel('Danceability')
ax3.set_ylabel('Count')
ax3.set_title('Song Danceability Like Distribution')
pos_dance.hist(alpha= 0.5, bins=30)
ax4 = fig2.add_subplot(331)
neg_dance.hist(alpha= 0.5, bins=30)

#Duration_ms
ax5 = fig2.add_subplot(332)
ax5.set_xlabel('Duration')
ax5.set_ylabel('Count')
ax5.set_title('Song Duration Like Distribution')
pos_duration.hist(alpha= 0.5, bins=30)
ax6 = fig2.add_subplot(332)
neg_duration.hist(alpha= 0.5, bins=30)

#Loudness
ax7 = fig2.add_subplot(333)
ax7.set_xlabel('Loudness')
ax7.set_ylabel('Count')
ax7.set_title('Song Loudness Like Distribution')
pos_loudness.hist(alpha= 0.5, bins=30)
ax8 = fig2.add_subplot(333)
neg_loudness.hist(alpha= 0.5, bins=30)

#Speechiness
ax9 = fig2.add_subplot(334)
ax9.set_xlabel('Speechiness')
ax9.set_ylabel('Count')
ax9.set_title('Song Speechiness Like Distribution')
pos_speechiness.hist(alpha= 0.5, bins=30)
ax10 = fig2.add_subplot(334)
neg_speechiness.hist(alpha= 0.5, bins=30)

#Valence
ax11 = fig2.add_subplot(335)
ax11.set_xlabel('Valence')
ax11.set_ylabel('Count')
ax11.set_title('Song Valence Like Distribution')
pos_valence.hist(alpha= 0.5, bins=30)
ax12 = fig2.add_subplot(335)
neg_valence.hist(alpha= 0.5, bins=30)

#Energy
ax13 = fig2.add_subplot(336)
ax13.set_xlabel('Energy')
ax13.set_ylabel('Count')
ax13.set_title('Song Energy Like Distribution')
pos_energy.hist(alpha= 0.5, bins=30)
ax14 = fig2.add_subplot(336)
neg_energy.hist(alpha= 0.5, bins=30)

#Key
ax15 = fig2.add_subplot(337)
ax15.set_xlabel('Key')
ax15.set_ylabel('Count')
ax15.set_title('Song Key Like Distribution')
pos_key.hist(alpha= 0.5, bins=30)
ax16 = fig2.add_subplot(337)
neg_key.hist(alpha= 0.5, bins=30)

#Key
ax15 = fig2.add_subplot(338)
ax15.set_xlabel('Popularity')
ax15.set_ylabel('Count')
ax15.set_title('Popularity Distribution')
pos_popularity.hist(alpha= 0.5, bins=30)
ax16 = fig2.add_subplot(338)
neg_popularity.hist(alpha= 0.5, bins=30)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Wewh, now that we have graphs galore, lets actually get into some different classifiers and see how they preform!

# %%
#Define the set of features that we want to look at
features = ["danceability", "loudness", "valence", "energy", "instrumentalness", "acousticness", "key", "speechiness","duration_ms"]

# %%
#Split the data into x and y test and train sets to feed them into a bunch of classifiers!
x_train = train[features]
y_train = train["target"]

x_test = test[features]
y_test = test["target"]

# %% [markdown]
# 1) A Decision Tree Classifier
# - A decision tree classifier is often the easiest to visualize, so we will start with it first
# - All it is is pretty much a decision tree based off the features so you can trace the path down and visually see how it makes decisions. This is nice to visualize but it isn't all that good at predicting this data.

# %%
c = DecisionTreeClassifier(min_samples_split=100)
dt = c.fit(x_train, y_train)

# %%
def show_tree(InputTree, features, path):
    f = io.StringIO()
    tree.export_graphviz(InputTree, out_file=f, feature_names=features)
    pydotplus.graph_from_dot_data(f.getvalue()).write_png(path)
    img = misc.imread(path)
    plt.rcParams["figure.figsize"] = (20,20)
    plt.imshow(img)
show_tree(dt, features, "dec_tree.png")

# %% [markdown]
# This is how we will see how our different classifiers do, by predicting the results on the test data and then figuring out how well they did.

# %%
y_pred = c.predict(x_test)
score = accuracy_score(y_test, y_pred) * 100
print("Accuracy using Decision Tree: ", round(score, 1), "%")
# Out:
# Accuracy using Decision Tree:  80.0 %

# %% [markdown]
# # A Bunch More Classifier Models
# - There are some of these that take a bunch of time to finish, I wouldnt recommend running all them unless you are really intrested in the results

# %% [markdown]
# ## The ones that take less time

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(3)
knn.fit(x_train, y_train)
knn_pred = c.predict(x_test)
score = accuracy_score(y_test, knn_pred) * 100
print("Accuracy using Knn Tree: ", round(score, 1), "%")
# Out:
# Accuracy using Knn Tree:  80.0 %

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier()
mlp.fit(x_train, y_train)
mlp_pred = mlp.predict(x_test)
score = accuracy_score(y_test, mlp_pred) * 100
print("Accuracy using mlp Tree: ", round(score, 1), "%")
# Out:
# Accuracy using mlp Tree:  40.4 %

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
forest.fit(x_train, y_train)
forest_pred = forest.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, forest_pred) * 100
print("Accuracy using random forest: ", round(score, 1), "%")
# Out:
# Accuracy using random forest:  80.5 %

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=100)
ada.fit(x_train, y_train)
ada_pred = ada.predict(x_test)
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, ada_pred) * 100
print("Accuracy using ada: ", round(score, 1), "%")
# Out:
# Accuracy using ada:  85.5 %

# %%
from sklearn.naive_bayes import GaussianNB
gauss = GaussianNB()
gauss.fit(x_train, y_train)
gauss_pred = gauss.predict(x_test)
score = accuracy_score(y_test, gauss_pred)*100
print("Accuracy using gauss: ", round(score, 1), "%")
# Out:
# Accuracy using gauss:  55.6 %

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=3, random_state=0)
k_means.fit(x_train, y_train)
predicted= k_means.predict(x_test)
score = accuracy_score(y_test, predicted)*100
print("Accuracy using Kmeans: ", round(score, 1), "%")
# Out:
# Accuracy using Kmeans:  45.4 %

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=.1, max_depth=1, random_state=0)
gbc.fit(x_train, y_train)
predicted = gbc.predict(x_test)
score = accuracy_score(y_test, predicted)*100
print("Accuracy using Gbc: ", round(score, 1), "%")
# Out:
# Accuracy using Gbc:  84.7 %

# %% [markdown]
# ## The ones that take more time

# %%
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
# qda = QuadraticDiscriminantAnalysis()
# qda.fit(x_train, y_train)
# qda_pred = qda.predict(x_test)
# score = accuracy_score(y_test, qda_pred)*100
# print("Accuracy using qda: ", round(score, 1), "%")

# %%
# from sklearn.svm import SVC
# svc_lin = SVC(kernel="linear", C=0.025)
# svc_lin.fit(x_train, y_train)
# svc_pred = svc_lin.predict(x_test)
# from sklearn.metrics import accuracy_score
# score = accuracy_score(y_test, svc_pred) * 100
# print("Accuracy using svc linear: ", round(score, 1), "%")

# %%
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# gpc = GaussianProcessClassifier(1.0 * RBF(1.0), warm_start=True)
# gpc.fit(x_train, y_train)
# gpc_pred = gpc.predict(x_test)
# from sklearn.metrics import accuracy_score
# score = accuracy_score(y_test, gpc_pred) * 100
# print("Accuracy using gpc: ", round(score, 1), "%")

# %% [markdown]
# # Now we should have a classifier with the highest accuracy score

# %%
# Request to modify playlists
username = "1287242681"
scope = 'playlist-modify-private playlist-modify-public playlist-read-private user-library-read'
token = util.prompt_for_user_token(username, scope)
#Good Playlist
if token:
    sp = spotipy.Spotify(auth=token)

# %% [markdown]
# ## Now we need to pick a playlist you want you classifier to find songs you like in...
# - Use the same thing you used to find the good and bad playlists to specify this new playlist you've taken an intrest in.

# %%
playlistToFindSongsYouLikeIn = sp.user_playlist("spotify", "37i9dQZEVXcFqDuJHHirGk")

newPlaylist_tracks = playlistToFindSongsYouLikeIn["tracks"]
newPlaylist_songs = newPlaylist_tracks["items"] 
while newPlaylist_tracks['next']:
    newPlaylist_tracks = sp.next(newPlaylist_tracks)
    for song in newPlaylist_tracks["items"]:
        newPlaylist_songs.append(song)
        
newPlaylist_song_ids = [] 
print(len(newPlaylist_songs))
for i in range(len(newPlaylist_songs)):
    newPlaylist_song_ids.append(newPlaylist_songs[i]['track']['id'])
    
newPlaylist_features = []
j = 0
for i in range(0,len(newPlaylist_song_ids),50):
    audio_features = sp.audio_features(newPlaylist_song_ids[i:i+50])
    for track in audio_features:
        track['song_title'] = newPlaylist_songs[j]['track']['name']
        track['artist'] = newPlaylist_songs[j]['track']['artists'][0]['name']
        j= j + 1
        newPlaylist_features.append(track)
print(len(newPlaylist_features))

playlistToLookAtFeatures = pd.DataFrame(newPlaylist_features)
# Out:
# 30
# 30

# %% [markdown]
# # We just loaded in your new tracks and audio features for those tracks
# - Now all we have to do is find the highest accuracy value out of all you classifiers (for me it was gdc) and predict what we will have over the new playlist

# %% [markdown]
# ### Quick aside: you can put these into a new playlist as well, just use the sp.user_playlist_add_tracks function
# - The function looks like this user_playlist_add_tracks("username", "playlist_id", "track_id_to_add")

# %%
pred = gbc.predict(playlistToLookAtFeatures[features])

likedSongs = 0
i = 0
for prediction in pred:
    if(prediction == 1):
        print ("Song: " + playlistToLookAtFeatures["song_title"][i] + ", By: "+ playlistToLookAtFeatures["artist"][i])
        #sp.user_playlist_add_tracks("1287242681", "7eIX1zvtpZR3M3rYFVA7DF", [test['id'][i]])
        likedSongs= likedSongs + 1
    i = i +1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68971640780f> in <module>()
# ----> 1 pred = gbc.predict(playlistToLookAtFeatures[features])
#       2
#       3 likedSongs = 0
#       4 i = 0
#       5 for prediction in pred:
#
# NameError: name 'gbc' is not defined

# %% [markdown]
# # There Ya Go!
# - This was my quick overview of my process of how I used classifiers and spoitfy to try and help me find tracks I might like in any playlist on spotify!
# - I want to make this tutorial less involved and figure out a way to make my classifiers better as well as using Tensorflow to make a model in order to do this for me.
